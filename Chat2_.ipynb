# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahmoudsabry3/Chat-visulization/blob/main/Chat2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 

import re
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
# !pip install emoji
import emoji
import itertools 
from collections import Counter
import warnings

# %matplotlib inline
# Out:
# ...
#      |████████████████████████████████| 133kB 6.7MB/s
# ...

# %%
df= pd.read_csv('https://raw.githubusercontent.com/Mahmoudsabry3/Chat-visulization/main/Aislin_and_Jeff.csv',sep = ';')

# %%
df2 = df.copy()
df2.MessageBody.sample(5)
# Out:
# 81596                        Look at my smiley pumpkin !!!
# 32924     The matress is one of the first priories I think
# 16872    Hahaha you can talk to me every day you want b...
# 27747    It’s hot as ballz lol and I would give just ab...
# 2064          Aislin orgasms are definitely on the list :)
# Name: MessageBody, dtype: object

# %%
df2.drop(columns=['MediaType', 'MediaLink'],inplace= True)

# %%
df2.replace(to_replace ="+1 (229) 854-4008", 
                 value ="Aislinr",inplace= True) 
df2.UserPhone.replace(to_replace =12298544008, 
                 value ="Aislinr's phone",inplace= True) 
df2.UserPhone.replace(to_replace =18565355675, 
                 value ="Jeff's phone",inplace= True)

# %%
df3 = df2.iloc[20000:30000,:]

# %%
comment_words = ' '

# stopwords --> Words to be avoided while forming the WordCloud,
# removed really common words like "yeah" and "okay".
stopwords = STOPWORDS.update(['jpeg','mp4', 'invite', 'joined', 'message', 'deleted', 'yeah', 'hai', 'yes', 'okay', 'ok', 'will', 'use', 'using', 'one', 'know', 'guy', 'group', 'media', 'omitted'])


# iterate through the DataFrame.
for val in df3.MessageBody:
    
    # typecaste each val to string.
    val = str(val) 
    
    # split the value.7
    tokens = val.split() 
    
    # Converts each token into lowercase.
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 600, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 8).generate(comment_words)

# %%
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7F5F15BE6790>
